# %%
# %config Completer.use_jedi = False
import pandas as pd
import numpy as np
pd.options.display.max_rows=1000
pd.options.display.max_columns=1000
import math
import re

# %%
DATA_DIR = '/home/sahil/data/av/AV_LTFS3/data/'

# %%
train = pd.read_csv(DATA_DIR+'train_Data.csv')
train_bur = pd.read_csv(DATA_DIR+'train_bureau.csv')
test_bur = pd.read_csv(DATA_DIR+'test_bureau.csv')

# %%
bur_df = pd.concat((train_bur,test_bur),axis=0)

# %%
train_bur.shape,train.shape,test_bur.shape,bur_df.shape
# Out:
# ((560844, 25), (128655, 26), (64019, 25), (624863, 25))

# %% [markdown]
# ##### date conversion and extracting payment hist start and end date

# %%
train['DisbursalDate'] = pd.to_datetime(train['DisbursalDate'])

bur_df.sort_values(['ID','DATE-REPORTED'],ascending=[True,False],inplace=True)
bur_df = bur_df.drop_duplicates(['ID','DISBURSED-DT','CONTRIBUTOR-TYPE','DISBURSED-AMT/HIGH CREDIT'],keep='first')
bur_df['min_reported_date'] = bur_df['REPORTED DATE - HIST'].str[:-1].fillna('').str.split(',').apply(min).replace('',np.NaN)
bur_df['max_reported_date'] = bur_df['REPORTED DATE - HIST'].str[:-1].fillna('').str.split(',').apply(max).replace('',np.NaN)
bur_df['DISBURSED-DT'] = pd.to_datetime(bur_df['DISBURSED-DT'])
bur_df['CLOSE-DT'] = pd.to_datetime(bur_df['CLOSE-DT'],errors='coerce')
bur_df['LAST-PAYMENT-DATE'] = pd.to_datetime(bur_df['LAST-PAYMENT-DATE'],errors='coerce')
bur_df['max_reported_date'] = pd.to_datetime(bur_df['max_reported_date'],format='%Y%m%d',errors='coerce')
bur_df['min_reported_date'] = pd.to_datetime(bur_df['min_reported_date'],format='%Y%m%d',errors='coerce')

# %%
bur_df.head()
# Out:
#    ID  SELF-INDICATOR MATCH-TYPE             ACCT-TYPE CONTRIBUTOR-TYPE  \
# 2   1            True    PRIMARY          Tractor Loan              NBF
# 1   1           False    PRIMARY  Auto Loan (Personal)              NAB
# 6   1           False    PRIMARY  Auto Loan (Personal)              NAB
# 0   1           False    PRIMARY             Overdraft              NAB
# 5   1           False    PRIMARY           Credit Card              NAB
#
#   DATE-REPORTED OWNERSHIP-IND ACCOUNT-STATUS DISBURSED-DT   CLOSE-DT  \
# 2    2020-01-31    Individual         Active   2019-08-30        NaT
# 1    2019-12-31    Individual         Active   2018-03-19        NaT
# 6    2019-12-31    Individual         Active   2018-11-15        NaT
# 0    2018-04-30    Individual     Delinquent   2015-10-05        NaT
# 5    2018-04-30    Individual         Closed   2018-01-11 2018-03-13
#
#   LAST-PAYMENT-DATE CREDIT-LIMIT/SANC AMT DISBURSED-AMT/HIGH CREDIT  \
# 2               NaT                   NaN                  1,45,000
# 1        2019-12-19                   NaN                    44,000
# 6        2019-12-15                   NaN                  5,00,000
# 0        2018-02-27                   NaN                    37,352
# 5               NaT                50,000                         0
#
#   INSTALLMENT-AMT CURRENT-BAL INSTALLMENT-FREQUENCY OVERDUE-AMT  \
# 2             NaN    1,16,087                   NaN           0
# 1   1,405/Monthly      20,797                   F03         NaN
# 6   7,934/Monthly    4,43,769                   F03         NaN
# 0             NaN      37,873                   NaN      37,873
# 5             NaN           0                   NaN         NaN
#
#    WRITE-OFF-AMT ASSET_CLASS  \
# 2            0.0         NaN
# 1            0.0    Standard
# 6            0.0    Standard
# 0            0.0    Standard
# 5            0.0    Standard
#
#                                 REPORTED DATE - HIST  \
# 2  20200131,20191231,20191130,20191031,20190930,2...
# 1  20191231,20191130,20191031,20190930,20190831,2...
# 6  20191231,20191130,20191031,20190930,20190831,2...
# 0                                 20180430,20180331,
# 5                        20180331,20180228,20180131,
#
#                                           DPD - HIST  \
# 2                                 000000000000000000
# 1  0000000000000000000000000000000000000000000000...
# 6         000000000000000000000000000000000000000000
# 0                                             030000
# 5                                          000000000
#
#                                       CUR BAL - HIST  \
# 2         116087,116087,145000,145000,145000,145000,
# 1  20797,21988,23174,24341,25504,26648,27780,2891...
# 6  443769,448365,453134,457687,462320,466802,4712...
# 0                                       37873,12820,
# 5                                     24650,17300,0,
#
#            AMT OVERDUE - HIST         AMT PAID - HIST  TENURE  \
# 2                0,0,0,0,0,0,                  ,,,,,,     NaN
# 1  ,,,,,,,,,,,,,,,,,,,,1452,,  ,,,,,,,,,,,,,,,,,,,,,,    36.0
# 6              ,,,,,,,,,,,,,,          ,,,,,,,,,,,,,,    84.0
# 0                     37873,,                      ,,     NaN
# 5                         ,,,                    ,,,,     NaN
#
#   min_reported_date max_reported_date
# 2        2019-08-31        2020-01-31
# 1        2018-03-31        2019-12-31
# 6        2018-11-30        2019-12-31
# 0        2018-03-31        2018-04-30
# 5        2018-01-31        2018-03-31

# %% [markdown]
# #### correcting the payment hist strings
#
# ###### when the report date is not present, dpd hist is always missing

# %%
bur_df['DPD - HIST'].isnull().sum(),bur_df['REPORTED DATE - HIST'].isnull().sum()
# Out:
# (8516, 8351)

# %%
bur_df['dpd_str_len'] = 3*bur_df['REPORTED DATE - HIST'].str[:-1].str.split(',').fillna('').apply(len)

# %%
# %%time
out=[]
for i,x in bur_df.iterrows():
    if not ((str(x['DPD - HIST']).find('E')>-1) | (type(x['DPD - HIST'])==float)):
        out.append('0'*(x['dpd_str_len']-len(x['DPD - HIST']))+x['DPD - HIST'])
    else:
        out.append(x['DPD - HIST'])
# Out:
# CPU times: user 46.3 s, sys: 120 ms, total: 46.4 s
# Wall time: 46.4 s

# %%
bur_df['dpd_string'] = out

# %% [markdown]
# #### correcting the amount error

# %%
for col in ['OVERDUE-AMT', 'DISBURSED-AMT/HIGH CREDIT','CURRENT-BAL']:
    amt = []
    for x in bur_df[col]:
        if type(x)!=float:
            x = x.split(',')
            if len(x)>1:
                x[1] = '0'+x[1] if len(x[1])==1 else x[1]
            x = ','.join(x)
        amt.append(x)
    bur_df['corrected'+col] = amt

# %%
amount_cols = ['CREDIT-LIMIT/SANC AMT','correctedDISBURSED-AMT/HIGH CREDIT', 'INSTALLMENT-AMT',
               'correctedCURRENT-BAL','correctedOVERDUE-AMT']
for col in amount_cols:
    bur_df[col] = bur_df[col].apply(lambda x:''.join(re.findall('[0-9]+',x)) if str(x)!='nan' else x).astype('float')

# %%
# amount_error = pd.read_csv('amount_systematic_error.csv')
# amount_error['DISBURSED-DT'] = pd.to_datetime(amount_error['DISBURSED-DT'])

# %%
# amount_error.head()

# %%
bur_df.head()
# Out:
#    ID  SELF-INDICATOR MATCH-TYPE             ACCT-TYPE CONTRIBUTOR-TYPE  \
# 2   1            True    PRIMARY          Tractor Loan              NBF
# 1   1           False    PRIMARY  Auto Loan (Personal)              NAB
# 6   1           False    PRIMARY  Auto Loan (Personal)              NAB
# 0   1           False    PRIMARY             Overdraft              NAB
# 5   1           False    PRIMARY           Credit Card              NAB
#
#   DATE-REPORTED OWNERSHIP-IND ACCOUNT-STATUS DISBURSED-DT   CLOSE-DT  \
# 2    2020-01-31    Individual         Active   2019-08-30        NaT
# 1    2019-12-31    Individual         Active   2018-03-19        NaT
# 6    2019-12-31    Individual         Active   2018-11-15        NaT
# 0    2018-04-30    Individual     Delinquent   2015-10-05        NaT
# 5    2018-04-30    Individual         Closed   2018-01-11 2018-03-13
#
#   LAST-PAYMENT-DATE  CREDIT-LIMIT/SANC AMT DISBURSED-AMT/HIGH CREDIT  \
# 2               NaT                    NaN                  1,45,000
# 1        2019-12-19                    NaN                    44,000
# 6        2019-12-15                    NaN                  5,00,000
# 0        2018-02-27                    NaN                    37,352
# 5               NaT                50000.0                         0
#
#    INSTALLMENT-AMT CURRENT-BAL INSTALLMENT-FREQUENCY OVERDUE-AMT  \
# 2              NaN    1,16,087                   NaN           0
# 1           1405.0      20,797                   F03         NaN
# 6           7934.0    4,43,769                   F03         NaN
# 0              NaN      37,873                   NaN      37,873
# 5              NaN           0                   NaN         NaN
#
#    WRITE-OFF-AMT ASSET_CLASS  \
# 2            0.0         NaN
# 1            0.0    Standard
# 6            0.0    Standard
# 0            0.0    Standard
# 5            0.0    Standard
#
#                                 REPORTED DATE - HIST  \
# 2  20200131,20191231,20191130,20191031,20190930,2...
# 1  20191231,20191130,20191031,20190930,20190831,2...
# 6  20191231,20191130,20191031,20190930,20190831,2...
# 0                                 20180430,20180331,
# 5                        20180331,20180228,20180131,
#
#                                           DPD - HIST  \
# 2                                 000000000000000000
# 1  0000000000000000000000000000000000000000000000...
# 6         000000000000000000000000000000000000000000
# 0                                             030000
# 5                                          000000000
#
#                                       CUR BAL - HIST  \
# 2         116087,116087,145000,145000,145000,145000,
# 1  20797,21988,23174,24341,25504,26648,27780,2891...
# 6  443769,448365,453134,457687,462320,466802,4712...
# 0                                       37873,12820,
# 5                                     24650,17300,0,
#
#            AMT OVERDUE - HIST         AMT PAID - HIST  TENURE  \
# 2                0,0,0,0,0,0,                  ,,,,,,     NaN
# 1  ,,,,,,,,,,,,,,,,,,,,1452,,  ,,,,,,,,,,,,,,,,,,,,,,    36.0
# 6              ,,,,,,,,,,,,,,          ,,,,,,,,,,,,,,    84.0
# 0                     37873,,                      ,,     NaN
# 5                         ,,,                    ,,,,     NaN
#
#   min_reported_date max_reported_date  dpd_str_len  \
# 2        2019-08-31        2020-01-31           18
# 1        2018-03-31        2019-12-31           66
# 6        2018-11-30        2019-12-31           42
# 0        2018-03-31        2018-04-30            6
# 5        2018-01-31        2018-03-31            9
#
#                                           dpd_string  correctedOVERDUE-AMT  \
# 2                                 000000000000000000                   0.0
# 1  0000000000000000000000000000000000000000000000...                   NaN
# 6         000000000000000000000000000000000000000000                   NaN
# 0                                             030000               37873.0
# 5                                          000000000                   NaN
#
#    correctedDISBURSED-AMT/HIGH CREDIT  correctedCURRENT-BAL
# 2                            145000.0              116087.0
# 1                             44000.0               20797.0
# 6                            500000.0              443769.0
# 0                             37352.0               37873.0
# 5                                 0.0                   0.0

# %%
bur_df.to_pickle(DATA_DIR+'bureau_data.pkl')

# %% [markdown]
# ### use a combination of max/min report data, close and disb date to find the loans disbursed during the tenor of the LTFS loan
